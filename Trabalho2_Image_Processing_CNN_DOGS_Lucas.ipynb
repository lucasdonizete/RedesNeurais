# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasdonizete/RedesNeurais/blob/main/Trabalho2_Image_Processing_CNN_DOGS_Lucas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Impotando bibliotecas para execução no código
from matplotlib import pyplot as plt #Biblioteca para gráficos
from sklearn import preprocessing #Usada para pre-tratamento e normalização de valores
from sklearn.model_selection import train_test_split #Usada para particionar os dados em treino e teste
from sklearn.metrics import classification_report #Para exibir métricas da classificação
import numpy as np #Cálculos e números
import pandas as pd #Apresentanção de informação no formato tipo uma tabela
import cv2 #Tratamento de imagem
import random #Usada para gerar número aleatório
import zipfile  #Usada para descompactar o material
from keras.models import Sequential #Convolução
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization #Biblioteca para uso da convolução

# %%
#Baixando as fotos
# !gdown --id 1SGIUSATQ0lQXv4nXOjmsmlbVPhfBEeSO
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SGIUSATQ0lQXv4nXOjmsmlbVPhfBEeSO
# To: /content/ann_dogs.zip
# 6.82MB [00:00, 106MB/s]

# %%
#Descompatando as fotos e extraindo
import zipfile
file_name = zipfile.ZipFile('ann_dogs.zip', 'r')
file_name.extractall()

# %%
# Carrengado as fotos e tratamento de tamanho e cor
FILE='ann_dogs.zip'
Img_Size = 100
img_name=[]
x_gray=[]
x_original = []
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)
        x_gray.append(cv2.resize(cv2.imread(name, 3),(Img_Size,Img_Size)))

# %%
# coloca as tres primeiras letras e colocou na lista de todas as imagens
y_names = [] 
for yy in img_name:
  name = yy[9]+yy[10]+yy[11]
  y_names.append(name)

# %%
#criacao das listas da ann
unique_list = []    
for yy in y_names:
  if yy not in unique_list:
    unique_list.append(yy)
unique_list
# Out:
# ['BAS', 'BUL', 'LAB', 'POO']

# %%
n = len(unique_list)
y = [] #lista em branco
for yy in y_names:
  for i in range(n):
    if(yy == unique_list[i]):
      y.append(i)

# %%
#mostra fotos aleatorias da biblioteca
num = len(y_names)
plt.figure(figsize=(16, 16))
for i in range(16): 
  ax = plt.subplot(4, 4, i + 1)
  kk = random.randrange(num) 
  plt.imshow(x_gray[kk])
  plt.title(y_names[kk])
  plt.axis("off")

# %%
 #transforma as fotos/matrizes em linhas 
x_data = []
for xx in x_gray:
  x_data.append(xx.ravel())

X = pd.DataFrame(x_data)

# %%
#separando os dataset em test e train
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.20, shuffle=True, random_state=3)

# %%
# helper
def ynindicator(y):
  N = len(y)
  K = len(set(y))
  I = np.zeros((N, K))
  I[np.arange(N), y] = 1
  return I
#Tratamento e "normalização dos valores"
X_train = np.array(X_train)
Y_train = np.array(Y_train)
K = len(set(Y_train))

X_train = X_train.reshape(-1, Img_Size, Img_Size, 3) / 255.0
Y_train = Y_train.astype(np.int32)
Y_train = ynindicator(Y_train)

X_test = np.array(X_test )
Y_test = np.array(Y_test)
X_test = X_test.reshape(-1, Img_Size, Img_Size, 3) / 255.0
Y_test = Y_test.astype(np.int32)
Y_test = ynindicator(Y_test)

# sequenciamento das fotos
model = Sequential()

#Convulução dos dados
model.add(Conv2D(input_shape=(Img_Size, Img_Size, 3), filters=32, kernel_size=(10, 10)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=64, kernel_size=(5, 5)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=128, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(units=150))
model.add(Activation('relu'))
model.add(Dropout(0.30))
model.add(Dense(units=K))
model.add(Activation('softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Apresenta métricas resultados da classficação
r = model.fit(X_train, Y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 18s 56ms/step - loss: 4.5375 - accuracy: 0.3423
# Epoch 2/50
# 8/8 [==============================] - 0s 18ms/step - loss: 1.9426 - accuracy: 0.4397
# Epoch 3/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.9570 - accuracy: 0.6344
# Epoch 4/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.7795 - accuracy: 0.6372
# Epoch 5/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6987 - accuracy: 0.7615
# Epoch 6/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5870 - accuracy: 0.7651
# Epoch 7/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6018 - accuracy: 0.7369
# Epoch 8/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4703 - accuracy: 0.8172
# Epoch 9/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3796 - accuracy: 0.8475
# Epoch 10/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4063 - accuracy: 0.8732
# Epoch 11/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2791 - accuracy: 0.8834
# Epoch 12/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2210 - accuracy: 0.9344
# Epoch 13/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2088 - accuracy: 0.9379
# Epoch 14/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2081 - accuracy: 0.9235
# Epoch 15/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.1533 - accuracy: 0.9659
# Epoch 16/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1298 - accuracy: 0.9650
# Epoch 17/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1352 - accuracy: 0.9259
# Epoch 18/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1301 - accuracy: 0.9501
# Epoch 19/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1206 - accuracy: 0.9662
# Epoch 20/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1515 - accuracy: 0.9571
# Epoch 21/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1213 - accuracy: 0.9701
# Epoch 22/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1058 - accuracy: 0.9759
# Epoch 23/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0732 - accuracy: 0.9678
# Epoch 24/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0942 - accuracy: 0.9682
# Epoch 25/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0550 - accuracy: 0.9980
# Epoch 26/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0702 - accuracy: 0.9728
# Epoch 27/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0565 - accuracy: 0.9901
# Epoch 28/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0475 - accuracy: 0.9801
# Epoch 29/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0467 - accuracy: 0.9873
# Epoch 30/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0362 - accuracy: 0.9965
# Epoch 31/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0408 - accuracy: 0.9982
# Epoch 32/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0660 - accuracy: 0.9782
# Epoch 33/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0972 - accuracy: 0.9560
# Epoch 34/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0392 - accuracy: 0.9936
# Epoch 35/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0449 - accuracy: 0.9915
# Epoch 36/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0446 - accuracy: 0.9953
# Epoch 37/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0432 - accuracy: 0.9854
# Epoch 38/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0542 - accuracy: 0.9753
# Epoch 39/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0214 - accuracy: 0.9965
# Epoch 40/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0430 - accuracy: 0.9936
# Epoch 41/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0429 - accuracy: 0.9867
# Epoch 42/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 43/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0295 - accuracy: 0.9854
# Epoch 44/50
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0224 - accuracy: 0.9889
# Epoch 45/50
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 46/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0238 - accuracy: 0.9887
# Epoch 47/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0194 - accuracy: 0.9930
# Epoch 48/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0536 - accuracy: 0.9721
# Epoch 49/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0384 - accuracy: 0.9842
# Epoch 50/50
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0341 - accuracy: 1.0000

# %%
# Plota a tendência de loss
plt.plot(r.history['loss'], label='loss')
plt.legend()
plt.show()

# %%
# Plota a tendência da acurácia
plt.plot(r.history['accuracy'], label='acc')
plt.legend()
plt.show()

# %%
#Avalia a qualidade do modelo de classficação para a parte do Teste
ynew = model.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
N_test = len(ynew)

# %%
y_resp = (model.predict(X_test) > 0.5).astype("int32")

# %%
y_class = np.zeros(N_test,dtype=int)
for k in range(N_test):
  for kk in range(K):
    if(Y_test[k,kk] == 1):
      y_class[k] = kk
y_true = y_class.copy()

# %%
y_class = np.zeros(N_test,dtype=int)
for k in range(N_test):
  for kk in range(K):
    if(y_resp[k,kk] == 1):
      y_class[k] = kk
y_pred = y_class.copy()

# %%
#Métricas da qualidade da classificação para o Teste
target_names = ['Basset', 'Bulldog', 'Labrador', 'Poodle']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Basset       0.90      0.83      0.86        23
#      Bulldog       0.33      0.20      0.25         5
#     Labrador       0.76      0.70      0.73        23
#       Poodle       0.59      0.91      0.71        11
#
#     accuracy                           0.74        62
#    macro avg       0.65      0.66      0.64        62
# weighted avg       0.75      0.74      0.74        62
