# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasdonizete/RedesNeurais/blob/main/Trabalho2_DOGS_Image_Processing_CONV_Lucas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Impotando bibliotecas para execução no código
from matplotlib import pyplot as plt #Biblioteca para gráficos
from sklearn import preprocessing #Usada para pre-tratamento e normalização de valores
from sklearn.model_selection import train_test_split #Usada para particionar os dados em treino e teste
from sklearn.metrics import classification_report #Para exibir métricas da classificação
import numpy as np #Cálculos e números
import pandas as pd #Apresentanção de informação no formato tipo uma tabela
import cv2 #Tratamento de imagem
import random #Usada para gerar número aleatório
import zipfile  #Usada para descompactar o material
from keras.models import Sequential #Convolução
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization #Biblioteca para uso da convolução

# %%
#Baixando as fotos
# !gdown --id 1SGIUSATQ0lQXv4nXOjmsmlbVPhfBEeSO
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1SGIUSATQ0lQXv4nXOjmsmlbVPhfBEeSO
# To: /content/ann_dogs.zip
# 6.82MB [00:00, 60.1MB/s]

# %%
#Descompatando as fotos e extraindo
import zipfile
file_name = zipfile.ZipFile('ann_dogs.zip', 'r')
file_name.extractall()

# %%
# Carrengado as fotos e tratamento de tamanho e cor
FILE='ann_dogs.zip'
Img_Size = 100
img_name=[]
x_gray=[]
x_original = []
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)
        x_gray.append(cv2.resize(cv2.imread(name, 3),(Img_Size,Img_Size)))

# %%
# coloca as tres primeiras letras e colocou na lista de todas as imagens
y_names = [] 
for yy in img_name:
  name = yy[9]+yy[10]+yy[11]
  y_names.append(name)

# %%
#criacao das listas da ann
unique_list = []    
for yy in y_names:
  if yy not in unique_list:
    unique_list.append(yy)
unique_list
# Out:
# ['BAS', 'BUL', 'LAB', 'POO']

# %%
n = len(unique_list)
y = [] #lista em branco
for yy in y_names:
  for i in range(n):
    if(yy == unique_list[i]):
      y.append(i)

# %%
#mostra fotos aleatorias da biblioteca
num = len(y_names)
plt.figure(figsize=(16, 16))
for i in range(16): 
  ax = plt.subplot(4, 4, i + 1)
  kk = random.randrange(num) 
  plt.imshow(x_gray[kk])
  plt.title(y_names[kk])
  plt.axis("off")

# %%
 #transforma as fotos/matrizes em linhas 
x_data = []
for xx in x_gray:
  x_data.append(xx.ravel())

X = pd.DataFrame(x_data)

# %%
#separando os dataset em test e train
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.20, shuffle=True, random_state=3)

# %%
# helper
def ynindicator(y):
  N = len(y)
  K = len(set(y))
  I = np.zeros((N, K))
  I[np.arange(N), y] = 1
  return I
#Tratamento e "normalização dos valores"
X_train = np.array(X_train)
Y_train = np.array(Y_train)
K = len(set(Y_train))

X_train = X_train.reshape(-1, Img_Size, Img_Size, 3) / 255.0
Y_train = Y_train.astype(np.int32)
Y_train = ynindicator(Y_train)

X_test = np.array(X_test )
Y_test = np.array(Y_test)
X_test = X_test.reshape(-1, Img_Size, Img_Size, 3) / 255.0
Y_test = Y_test.astype(np.int32)
Y_test = ynindicator(Y_test)

# sequenciamento das fotos
model = Sequential()

#Convulução dos dados
model.add(Conv2D(input_shape=(Img_Size, Img_Size, 3), filters=32, kernel_size=(10, 10)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=64, kernel_size=(5, 5)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Conv2D(filters=128, kernel_size=(3, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(units=120))
model.add(Activation('relu'))
model.add(Dropout(0.30))
model.add(Dense(units=K))
model.add(Activation('softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Apresenta métricas resultados da classficação
r = model.fit(X_train, Y_train, epochs=40, batch_size=32)
# Out:
# Epoch 1/40
# 8/8 [==============================] - 46s 58ms/step - loss: 6.3653 - accuracy: 0.3182
# Epoch 2/40
# 8/8 [==============================] - 0s 17ms/step - loss: 3.3547 - accuracy: 0.4029
# Epoch 3/40
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2984 - accuracy: 0.5672
# Epoch 4/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9990 - accuracy: 0.6266
# Epoch 5/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.9321 - accuracy: 0.6166
# Epoch 6/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7100 - accuracy: 0.7288
# Epoch 7/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6581 - accuracy: 0.7346
# Epoch 8/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5514 - accuracy: 0.7660
# Epoch 9/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4825 - accuracy: 0.8296
# Epoch 10/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3823 - accuracy: 0.8885
# Epoch 11/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4021 - accuracy: 0.8526
# Epoch 12/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3949 - accuracy: 0.8450
# Epoch 13/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3653 - accuracy: 0.8566
# Epoch 14/40
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3068 - accuracy: 0.8924
# Epoch 15/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2755 - accuracy: 0.8980
# Epoch 16/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3081 - accuracy: 0.8726
# Epoch 17/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2064 - accuracy: 0.9288
# Epoch 18/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1908 - accuracy: 0.9426
# Epoch 19/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2269 - accuracy: 0.9128
# Epoch 20/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1556 - accuracy: 0.9728
# Epoch 21/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2197 - accuracy: 0.9153
# Epoch 22/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1693 - accuracy: 0.9474
# Epoch 23/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1434 - accuracy: 0.9563
# Epoch 24/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1750 - accuracy: 0.9158
# Epoch 25/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1413 - accuracy: 0.9448
# Epoch 26/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0968 - accuracy: 0.9817
# Epoch 27/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0805 - accuracy: 0.9886
# Epoch 28/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1103 - accuracy: 0.9739
# Epoch 29/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1370 - accuracy: 0.9367
# Epoch 30/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1118 - accuracy: 0.9655
# Epoch 31/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1292 - accuracy: 0.9531
# Epoch 32/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0947 - accuracy: 0.9690
# Epoch 33/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0763 - accuracy: 0.9692
# Epoch 34/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0894 - accuracy: 0.9707
# Epoch 35/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0817 - accuracy: 0.9827
# Epoch 36/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0701 - accuracy: 0.9871
# Epoch 37/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0478 - accuracy: 0.9953
# Epoch 38/40
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0749 - accuracy: 0.9721
# Epoch 39/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1109 - accuracy: 0.9626
# Epoch 40/40
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0656 - accuracy: 0.9828

# %%
# Plota a tendência de loss
plt.plot(r.history['loss'], label='loss')
plt.legend()
plt.show()

# %%
# Plota a tendência da acurácia
plt.plot(r.history['accuracy'], label='acc')
plt.legend()
plt.show()

# %%
#Avalia a qualidade do modelo de classficação para a parte do Teste
ynew = model.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
N_test = len(ynew)

# %%
y_resp = (model.predict(X_test) > 0.5).astype("int32")

# %%
y_class = np.zeros(N_test,dtype=int)
for k in range(N_test):
  for kk in range(K):
    if(Y_test[k,kk] == 1):
      y_class[k] = kk
y_true = y_class.copy()

# %%
y_class = np.zeros(N_test,dtype=int)
for k in range(N_test):
  for kk in range(K):
    if(y_resp[k,kk] == 1):
      y_class[k] = kk
y_pred = y_class.copy()

# %%
#Métricas da qualidade da classificação para o Teste
target_names = ['Basset', 'Bulldog', 'Labrador', 'Poodle']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Basset       0.73      0.96      0.83        23
#      Bulldog       0.00      0.00      0.00         5
#     Labrador       0.82      0.61      0.70        23
#       Poodle       0.60      0.82      0.69        11
#
#     accuracy                           0.73        62
#    macro avg       0.54      0.60      0.56        62
# weighted avg       0.68      0.73      0.69        62
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
